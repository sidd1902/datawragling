# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("d3.csv")   # importing detaset 3 named as 'd3' by me
df
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  29-01-2011       1   0     1   1    False        6           1
# 1        621  29-01-2011       1   0     1   2    False        6           1
# 2        622  29-01-2011       1   0     1   3    False        6           1
# 3        623  29-01-2011       1   0     1   4    False        6           1
# 4        624  29-01-2011       1   0     1   6    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %%
df.tail(10) #as you can see last some numbers are lower then first so printing them
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 380     1000  14-02-2011       1   0     2   7    False        1           1
# 381      611  28-01-2011       1   0     1  16    False        5           1
# 382      612  28-01-2011       1   0     1  17    False        5           1
# 383      613  28-01-2011       1   0     1  18    False        5           1
# 384      614  28-01-2011       1   0     1  19    False        5           2
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
#      temp   atemp   hum  windspeed  casual  registered  cnt
# 380  0.34  0.3030  0.46     0.2985       2          96   98
# ...

# %%
df0=pd.concat([df.tail(9), df], ignore_index=True) #its the last 9 rows that should be in first
df0
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        611  28-01-2011       1   0     1  16    False        5           1
# 1        612  28-01-2011       1   0     1  17    False        5           1
# 2        613  28-01-2011       1   0     1  18    False        5           1
# 3        614  28-01-2011       1   0     1  19    False        5           2
# 4        615  28-01-2011       1   0     1  20    False        5           2
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 394      615  28-01-2011       1   0     1  20    False        5           2
# 395      616  28-01-2011       1   0     1  21    False        5           2
# 396      617  28-01-2011       1   0     1  22    False        5           1
# 397      618  28-01-2011       1   0     1  23    False        5           1
# 398      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %%
df = df0.iloc[:-9]# deleting lst 9 rows as they are repitativ and belong to first only
df
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        611  28-01-2011       1   0     1  16    False        5           1
# 1        612  28-01-2011       1   0     1  17    False        5           1
# 2        613  28-01-2011       1   0     1  18    False        5           1
# 3        614  28-01-2011       1   0     1  19    False        5           2
# 4        615  28-01-2011       1   0     1  20    False        5           2
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      996  14-02-2011       1   0     2   3    False        1           1
# 386      997  14-02-2011       1   0     2   4    False        1           1
# 387      998  14-02-2011       1   0     2   5    False        1           1
# 388      999  14-02-2011       1   0     2   6    False        1           1
# 389     1000  14-02-2011       1   0     2   7    False        1           1
#
# ...

# %%
print(df.dtypes)#chacking data types
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday          bool
# weekday         int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
for i in df.columns:  
    unique_vals = df[i].unique()  
    print(f"Unique values in '{i}': {unique_vals}")
# Out:
# Unique values in 'instant': [ 611  612  613  614  615  616  617  618  619  620  621  622  623  624
#   625  626  627  628  629  630  631  632  633  634  635  636  637  638
#   639  640  641  642  643  644  645  646  647  648  649  650  651  652
#   653  654  655  656  657  658  659  660  661  662  663  664  665  666
#   667  668  669  670  671  672  673  674  675  676  677  678  679  680
#   681  682  683  684  685  686  687  688  689  690  691  692  693  694
#   695  696  697  698  699  700  701  702  703  704  705  706  707  708
#   709  710  711  712  713  714  715  716  717  718  719  720  721  722
#   723  724  725  726  727  728  729  730  731  732  733  734  735  736
#   737  738  739  740  741  742  743  744  745  746  747  748  749  750
#   751  752  753  754  755  756  757  758  759  760  761  762  763  764
#   765  766  767  768  769  770  771  772  773  774  775  776  777  778
#   779  780  781  782  783  784  785  786  787  788  789  790  791  792
# ...

# %%
dc=['yr','mnth'] #removing them as i alredy removed them from privious dataset
df.drop(columns=dc, inplace=True)
print(df.dtypes)
# Out:
# instant         int64
# dteday         object
# season          int64
# hr              int64
# holiday          bool
# weekday         int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object
# C:\Users\skhai\AppData\Local\Temp\ipykernel_8236\3912813716.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=dc, inplace=True)

# %%
for i in df.columns: #hadeling missing vals
    df.fillna(value={"i": 0}, inplace=True) 
    print("Missing values treated in ",i)
# Out:
# Missing values treated in  instant
# Missing values treated in  dteday
# Missing values treated in  season
# Missing values treated in  hr
# Missing values treated in  holiday
# Missing values treated in  weekday
# Missing values treated in  weathersit
# Missing values treated in  temp
# Missing values treated in  atemp
# Missing values treated in  hum
# Missing values treated in  windspeed
# Missing values treated in  casual
# Missing values treated in  registered
# Missing values treated in  cnt
# C:\Users\skhai\AppData\Local\Temp\ipykernel_8236\1625694139.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.fillna(value={"i": 0}, inplace=True)

# %%
df.hist(figsize=(20, 10))
plt.suptitle("Histograms of Numeric Columns")
plt.tight_layout()
plt.show()

# %%
df.plot(kind='box', subplots=True, layout=(1, len(df.select_dtypes(include=np.number).columns)), figsize=(20, 5), sharey=False)
plt.suptitle("Boxplots of Numeric Columns")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# %%
df1 = pd.read_csv("new_dataset.csv")  #imorting merged dataset from privious d1&d2
df1
# Out:
#      instant      dteday  season  hr  holiday  weekday  weathersit  temp  \
# 0          1  01-01-2011       1   0    False        6           1  0.24
# 1          2  01-01-2011       1   1    False        6           1  0.22
# 2          3  01-01-2011       1   2    False        6           1  0.22
# 3          4  01-01-2011       1   3    False        6           1  0.24
# 4          5  01-01-2011       1   4    False        6           1  0.24
# ..       ...         ...     ...  ..      ...      ...         ...   ...
# 605      606  28-01-2011       1  11    False        5           3  0.18
# 606      607  28-01-2011       1  12    False        5           3  0.18
# 607      608  28-01-2011       1  13    False        5           3  0.18
# 608      609  28-01-2011       1  14    False        5           3  0.22
# 609      610  28-01-2011       1  15    False        5           2  0.20
#
#       atemp   hum  windspeed  casual  registered  cnt
# ...

# %%
#as it was alredy prossed i m directly merging them
pd.merge(df, df1, on="instant", how="outer")# i have also tried inner left right but nothing shows disaerd output
# Out:
#      instant    dteday_x  season_x  hr_x holiday_x  weekday_x  weathersit_x  \
# 0          1         NaN       NaN   NaN       NaN        NaN           NaN
# 1          2         NaN       NaN   NaN       NaN        NaN           NaN
# 2          3         NaN       NaN   NaN       NaN        NaN           NaN
# 3          4         NaN       NaN   NaN       NaN        NaN           NaN
# 4          5         NaN       NaN   NaN       NaN        NaN           NaN
# ..       ...         ...       ...   ...       ...        ...           ...
# 995      996  14-02-2011       1.0   3.0     False        1.0           1.0
# 996      997  14-02-2011       1.0   4.0     False        1.0           1.0
# 997      998  14-02-2011       1.0   5.0     False        1.0           1.0
# 998      999  14-02-2011       1.0   6.0     False        1.0           1.0
# 999     1000  14-02-2011       1.0   7.0     False        1.0           1.0
#
# ...

# %%
pd.concat([df1, df], ignore_index=True)#here i used concat funtion to merge verticaly and gets output i wanted
# Out:
#      instant      dteday  season  hr  holiday  weekday  weathersit  temp  \
# 0          1  01-01-2011       1   0    False        6           1  0.24
# 1          2  01-01-2011       1   1    False        6           1  0.22
# 2          3  01-01-2011       1   2    False        6           1  0.22
# 3          4  01-01-2011       1   3    False        6           1  0.24
# 4          5  01-01-2011       1   4    False        6           1  0.24
# ..       ...         ...     ...  ..      ...      ...         ...   ...
# 995      996  14-02-2011       1   3    False        1           1  0.34
# 996      997  14-02-2011       1   4    False        1           1  0.32
# 997      998  14-02-2011       1   5    False        1           1  0.32
# 998      999  14-02-2011       1   6    False        1           1  0.34
# 999     1000  14-02-2011       1   7    False        1           1  0.34
#
#       atemp   hum  windspeed  casual  registered  cnt
# ...

# %%
df2=pd.concat([df1, df], ignore_index=True)#storing it in df2 to prosses

# %%
df2
# Out:
#      instant      dteday  season  hr  holiday  weekday  weathersit  temp  \
# 0          1  01-01-2011       1   0    False        6           1  0.24
# 1          2  01-01-2011       1   1    False        6           1  0.22
# 2          3  01-01-2011       1   2    False        6           1  0.22
# 3          4  01-01-2011       1   3    False        6           1  0.24
# 4          5  01-01-2011       1   4    False        6           1  0.24
# ..       ...         ...     ...  ..      ...      ...         ...   ...
# 995      996  14-02-2011       1   3    False        1           1  0.34
# 996      997  14-02-2011       1   4    False        1           1  0.32
# 997      998  14-02-2011       1   5    False        1           1  0.32
# 998      999  14-02-2011       1   6    False        1           1  0.34
# 999     1000  14-02-2011       1   7    False        1           1  0.34
#
#       atemp   hum  windspeed  casual  registered  cnt
# ...

# %%
df2.plot(kind='box', subplots=True, layout=(1, len(df.select_dtypes(include=np.number).columns)), figsize=(20, 5), sharey=False)
plt.suptitle("Boxplots of Numeric Columns")
plt.tight_layout()
plt.show()

# %%
#as youn can see their are some outliers in some colunms 
# Handle outliers using the IQR method for all numeric columns
numeric_cols = df2.select_dtypes(include=np.number).columns
for col in numeric_cols: #instid of handeling one by one i m adding loop here
    Q1 = df2[col].quantile(0.25)
    Q3 = df2[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    # Cap outliers
    df2[col] = np.where(df2[col] < lower_bound, lower_bound, np.where(df2[col] > upper_bound, upper_bound, df2[col]))

# %%
df2.plot(kind='box', subplots=True, layout=(1, len(df.select_dtypes(include=np.number).columns)), figsize=(20, 5), sharey=False)
plt.suptitle("Boxplots of Numeric Columns")
plt.tight_layout()
plt.show()             #lets see the dff

# %%
#you can see mager diff in both box plots

# %%
df2.to_csv("final_dataset.csv", index=False)# creating final detaset after handeling outliyers
